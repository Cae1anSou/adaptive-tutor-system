# %%
import pandas as pd
# Out:
# /Users/caoxinzhuo/code/CHI26/adaptive-tutor-system/.venv/lib/python3.12/site-packages/pydantic/_internal/_config.py:373: UserWarning: Valid config keys have changed in V2:
# * 'orm_mode' has been renamed to 'from_attributes'
#   warnings.warn(message, UserWarning)

# %%
allData: pd.DataFrame = pd.read_csv("Untitled form.csv")
allData
# Out:
#                        Timestamp Please enter your experiment ID.   \
# 0    2025/09/09 4:23:00 PM GMT+8                       baseline003
# 1    2025/09/09 4:29:57 PM GMT+8                       baseline001
# 2    2025/09/09 5:11:39 PM GMT+8                            exp004
# 3    2025/09/09 5:45:36 PM GMT+8                            exp003
# 4   2025/09/10 12:11:40 AM GMT+8                       baseline007
# 5   2025/09/10 12:38:51 AM GMT+8                       baseline008
# 6    2025/09/10 1:04:58 AM GMT+8                       baseline009
# 7    2025/09/10 1:21:52 AM GMT+8                       baseline004
# 8    2025/09/10 8:44:36 AM GMT+8                       baseline005
# 9   2025/09/11 12:19:02 AM GMT+8                            exp009
# 10  2025/09/11 12:23:52 AM GMT+8                            exp015
# 11  2025/09/11 12:37:40 AM GMT+8                            exp007
# 12   2025/09/11 1:20:59 AM GMT+8                          exp00121
# ...

# %%
# Out:
#                        Timestamp Please enter your experiment ID.   \
# 0    2025/09/09 4:29:57 PM GMT+8                       baseline001
# 1    2025/09/09 5:11:39 PM GMT+8                            exp004
# 2    2025/09/09 5:45:36 PM GMT+8                            exp003
# 3   2025/09/10 12:11:40 AM GMT+8                       baseline007
# 4   2025/09/10 12:38:51 AM GMT+8                       baseline008
# 5    2025/09/10 1:04:58 AM GMT+8                       baseline009
# 6    2025/09/10 1:21:52 AM GMT+8                       baseline004
# 7    2025/09/10 8:44:36 AM GMT+8                       baseline005
# 8   2025/09/11 12:19:02 AM GMT+8                            exp009
# 9   2025/09/11 12:23:52 AM GMT+8                            exp015
# 10  2025/09/11 12:37:40 AM GMT+8                            exp007
# 11   2025/09/11 1:20:59 AM GMT+8                          exp00121
# 12   2025/09/11 9:34:09 AM GMT+8                           exp0010
# ...
