# %%
import pandas as pd

# %%
allData: pd.DataFrame = pd.read_csv("Untitled form.csv")
allData

# %%
pd.read_csv('cleaned/module_feedback_long.csv').to_excel(
    'export.xlsx', index=False, engine="openpyxl"
)
